# %% [markdown]
# # Density and Contour Plots

# %% [markdown]
# Sometimes it is useful to display 3D data in two dimensions using contour or color-coded regions. There are three Matplotlib functions than can be helpful for this task: `plt.contour` for contour plots, `plt.contourf` for filled contour plots, and `plt.imshow` for showing images. Thsi section looks at several examples of using these. We'll start by setting us the notebook for plotting and importinh the functions we will use:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-white')
import numpy as np

# %% [markdown]
# ## Visualizing a 3D Function

# %% [markdown]
# We'll start by demonstrating a contour plot using a function $z=f(x,y)$, using the following particular choice for $f$:

# %%
def f(x,y):
    return np.sin(x)**10+np.cos(10+y*x)*np.cos(x)

# %% [markdown]
# A contour plot can be created with the `plt.contour` function. It takes three arguments: a grid of `x` values, a grid of `y` values. The `x` and `y` values represent positions on the plot, and the z values will be represented by the contour levels. Perhaps the most straightforward way to prepare such data is to use the `np.meshgrid` function, which builds two-dimensional grids from one-dimensional arrays:

# %%
x = np.linspace(0,5,50)
y = np.linspace(0,4,40)

X,Y = np.meshgrid(x,y)
Z = f(X,Y)

# %% [markdown]
# Now let's looks at this with a standard line-only contour plot:

# %%
plt.contour(X,Y,Z,colors='black');

# %% [markdown]
# Notice that by default when a single color is used, negative values are represented by dashed lines, and positive values bu solid lines. Alternatively, you can color-code the lines by specifying a colormap with the `cmap` argument. Here, we'll also specify that we want more lines to be drawn - 20 equalyy spaced intervals within the data range:

# %%
plt.contour(X,Y,Z,20,cmap='RdGy');

# %% [markdown]
# Here we chose the `RdGy` (short for Red-Gray) colormap which is a good choice for centered data. Matplotlib has a wide range of colormaps available, which you can easily browse in IPython by doing a tab completion on the `plt.cm` module:

# %% [markdown]
# Our plot is looking nicer, but the spaces between the lines may be a bit distracting. We can change this by switching to a filled contour plot using the `plt.contourf()` function (notice the `f` at the end), which uses largely the same syntax as `plt.contour()`.

# %% [markdown]
# Additonally, we'll add a `plt.colotbar()` command, which automatically creates as an additional axis with labeled color information for the plot:

# %%
plt.contourf(X,Y,Z,20,cmap='RdGy')
plt.colorbar();

# %% [markdown]
# The colorbar makes it clear that the black regions are "peaks", while the red regions are "valleys".

# %% [markdown]
# One potential issue with this plot is that it is a bit "splotchy". That is, the color steps are discrete rather than continuous, which is not always what is desired. You could remedy this by setting the number of contours to a very high number, but htis results in a rather inefficient plot: Matplotlib must render a new ploygon for each step in the level. A better way to handle this is to use the `plt.imshow()` function, which interprets a two-dimensional grid of data as an image:

# %%
plt.imshow(Z,extent=[0,5,0,5],origin='lower',
          cmap='RdGy')
plt.colorbar()
plt.axis(aspect='image');

# %% [markdown]
# There are a few potential gitchas with `imshow()`, however:
# - `plt.show()` doesn't accept an `x` and `y` grid, so you must manually specify the `extend[xmin,xmax,ymin,ymax]` of the image on the plot.
# - `plt.imshow()` by default follows the standard image array definition where the origin is in the upper left, not in the lower left as in most contour plots. This must be changed when showing gridded data.
# - `plt.imshow()` will automatically adjust the axis aspect ratio to match the input data; you can chnage this by setting, for example, `plt.axis(aspect='image')` to make `x` and `y` units match.

# %% [markdown]
# Finally, it can sometimes be useful to combine contour plots and image plots. Next, we'll use a partially transparent background image (with transparency set via the `alpha` parameter) and over-plot contours withlabels on the contours themsleves (using the `plt.clabel()` function):

# %%
contours = plt.contour(X,Y,Z, 3, colors='black')
plt.clabel(contours,inline=True,fontsize=8)

plt.imshow(Z,extent=[0,5,0,5], origin='lower',
          cmap='RdGy',alpha=0.5)
plt.colorbar();

# %% [markdown]
# The combination of these three functions - `plt.contour`, `plt.contourf`, and `plt.imshow` - gives nearly limitless possibilities for displaying thsi sort of three-dimensional data within a two-dimensional plot.
